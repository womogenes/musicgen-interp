# %%
import torch
import os
from pathlib import Path
import json
import matplotlib.pyplot as plt
from tqdm import tqdm
import numpy as np
from IPython.display import Audio, display
import random

# %%
METADATA_PATH = "/home/harinit9/orcd/pool/musicgen-data-nokey/tempo_metadata.json"

with open(METADATA_PATH) as fin:
    metadata = json.load(fin)

clips = random.sample(metadata, 10)

# %%
for clip in clips:
    print(clip["clip_id"], "bpm:", clip["tempo_bpm"], clip["audio_path"])
    display(Audio(clip["audio_path"]))
# Out:
# 0039 bpm: 0.0 /home/harinit9/orcd/pool/musicgen-data-nokey/audio/0039.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 0310 bpm: 138.89 /home/harinit9/orcd/pool/musicgen-data-nokey/audio/0310.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 0865 bpm: 56.82 /home/harinit9/orcd/pool/musicgen-data-nokey/audio/0865.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 0621 bpm: 50.0 /home/harinit9/orcd/pool/musicgen-data-nokey/audio/0621.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 0026 bpm: 120.97 /home/harinit9/orcd/pool/musicgen-data-nokey/audio/0026.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 0416 bpm: 85.23 /home/harinit9/orcd/pool/musicgen-data-nokey/audio/0416.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 0053 bpm: 89.29 /home/harinit9/orcd/pool/musicgen-data-nokey/audio/0053.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 0069 bpm: 83.33 /home/harinit9/orcd/pool/musicgen-data-nokey/audio/0069.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 0838 bpm: 15.31 /home/harinit9/orcd/pool/musicgen-data-nokey/audio/0838.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 0537 bpm: 208.33 /home/harinit9/orcd/pool/musicgen-data-nokey/audio/0537.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
acts = np.load("/home/wyf/orcd/pool/musicgen-activations-nokey/acts_by_layer/layer_22.npy")
acts_pooled = np.max(arr, axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_pooled = scaler.fit_transform(acts_pooled)
print(f"{X_pooled.shape=}")
# Out:
# X_pooled.shape=(1000, 2048)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_pooled)
print(f"{X_pca.shape=}")
# Out:
# X_pca.shape=(1000, 2)

# %%
# Color by specific key
keys = np.array([clip["key_info"]["key"] for clip in metadata])
unique_keys = np.unique(keys)

cmap = plt.cm.get_cmap("tab20", len(unique_keys))
for i, key in enumerate(unique_keys):
    mask = keys == key
    plt.scatter(X_pca[mask, 0], X_pca[mask, 1], c=[cmap(i)], label=key, alpha=0.6, s=20)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
plt.title("PCA of Layer 22 Activations (colored by key)")
plt.tight_layout()
